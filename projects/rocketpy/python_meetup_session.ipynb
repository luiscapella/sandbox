# %%
pip install rocketpy
# Out:
# Collecting rocketpy
#   Using cached rocketpy-0.9.9-py3-none-any.whl
# Requirement already satisfied: requests in /Users/capel010/.pyenv/versions/3.9.9/lib/python3.9/site-packages (from rocketpy) (2.27.1)
# Collecting numpy>=1.0
#   Using cached numpy-1.22.1-cp39-cp39-macosx_10_9_x86_64.whl (17.7 MB)
# Collecting scipy>=1.0
#   Using cached scipy-1.7.3-cp39-cp39-macosx_10_9_x86_64.whl (33.2 MB)
# Collecting matplotlib>=3.0
#   Using cached matplotlib-3.5.1-cp39-cp39-macosx_10_9_x86_64.whl (7.3 MB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/capel010/.pyenv/versions/3.9.9/lib/python3.9/site-packages (from matplotlib>=3.0->rocketpy) (2.8.2)
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/capel010/.pyenv/versions/3.9.9/lib/python3.9/site-packages (from matplotlib>=3.0->rocketpy) (3.0.7)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.29.0-py3-none-any.whl (895 kB)
# Collecting pillow>=6.2.0
#   Using cached Pillow-9.0.0-cp39-cp39-macosx_10_10_x86_64.whl (3.0 MB)
# Requirement already satisfied: packaging>=20.0 in /Users/capel010/.pyenv/versions/3.9.9/lib/python3.9/site-packages (from matplotlib>=3.0->rocketpy) (20.9)
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.3.2-cp39-cp39-macosx_10_9_x86_64.whl (61 kB)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/capel010/.pyenv/versions/3.9.9/lib/python3.9/site-packages (from requests->rocketpy) (2.0.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/capel010/.pyenv/versions/3.9.9/lib/python3.9/site-packages (from requests->rocketpy) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /Users/capel010/.pyenv/versions/3.9.9/lib/python3.9/site-packages (from requests->rocketpy) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/capel010/.pyenv/versions/3.9.9/lib/python3.9/site-packages (from requests->rocketpy) (1.26.8)
# Requirement already satisfied: six>=1.5 in /Users/capel010/.pyenv/versions/3.9.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.0->rocketpy) (1.16.0)
# Installing collected packages: pillow, numpy, kiwisolver, fonttools, cycler, scipy, matplotlib, rocketpy
# Successfully installed cycler-0.11.0 fonttools-4.29.0 kiwisolver-1.3.2 matplotlib-3.5.1 numpy-1.22.1 pillow-9.0.0 rocketpy-0.9.9 scipy-1.7.3
# Note: you may need to restart the kernel to use updated packages.

# %%
pip show rocketpy
# Out:
# Name: rocketpy
# Version: 0.9.9
# Summary: Advanced 6-DOF trajectory simulation for High-Power Rocketry.
# Home-page: https://github.com/giovaniceotto/RocketPy
# Author: Giovani Hidalgo Ceotto
# Author-email: ghceotto@gmail.com
# License: UNKNOWN
# Location: /Users/capel010/.pyenv/versions/3.9.9/lib/python3.9/site-packages
# Requires: matplotlib, numpy, requests, scipy
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
from rocketpy import Environment, Rocket, SolidMotor, Flight

# %%
Env = Environment(
    railLength=5.2
)

# %%
Pro75M1670 = SolidMotor(
    thrustSource="data/motors/cesaroni_M1670.eng",
    burnOut=3.9,
    grainNumber=5,
    grainSeparation=5/1000,
    grainDensity=1815,
    grainOuterRadius=33/1000,
    grainInitialInnerRadius=15/1000,
    grainInitialHeight=120/1000,
    nozzleRadius=33/1000,
    throatRadius=11/1000,
    interpolationMethod='linear'
)

# %%
Calisto = Rocket(
    motor=Pro75M1670,
    radius=127/2000,
    mass=19.197-2.956,
    inertiaI=6.60,
    inertiaZ=0.0351,
    distanceRocketNozzle=-1.255,
    distanceRocketPropellant=-0.85704,
    powerOffDrag='data/calisto/power_off_drag_curve.csv',
    powerOnDrag='data/calisto/power_on_drag_curve.csv'
)

Calisto.setRailButtons([0.2, -0.5])

NoseCone = Calisto.addNose(length=0.55829, kind="vonKarman", distanceToCM=0.71971)

FinSet = Calisto.addFins(4, span=0.100, rootChord=0.120, tipChord=0.040, distanceToCM=-1.04956)

Tail = Calisto.addTail(topRadius=0.0635, bottomRadius=0.0435, length=0.060, distanceToCM=-1.194656)

# %%
def drogueTrigger(p, y):
    return True if y[5] < 0 else False

def mainTrigger(p, y):
    return True if y[5] < 0 and y[2] < 800 else False

Main = Calisto.addParachute('Main',
                            CdS=10.0,
                            trigger=mainTrigger,
                            samplingRate=105,
                            lag=1.5,
                            noise=(0, 8.3, 0.5))

Drogue = Calisto.addParachute('Drogue',
                              CdS=1.0,
                              trigger=drogueTrigger,
                              samplingRate=105,
                              lag=1.5,
                              noise=(0, 8.3, 0.5))

# %%
TestFlight = Flight(rocket=Calisto, environment=Env, inclination=85, heading=0)

# %%
TestFlight.info()
# Out:
# Surface Wind Conditions
#
# Frontal Surface Wind Speed: 0.00 m/s
# Lateral Surface Wind Speed: 0.00 m/s
#
#
#  Rail Departure State
#
# Rail Departure Time: 0.364 s
# Rail Departure Velocity: 25.874 m/s
# Rail Departure Static Margin: 2.134 c
# Rail Departure Angle of Attack: 0.000°
# Rail Departure Thrust-Weight Ratio: 10.146
# Rail Departure Reynolds Number: 2.249e+05
#
#
# BurnOut State
#
# BurnOut time: 3.900 s
# Altitude at burnOut: 654.062 m (AGL)
# Rocket velocity at burnOut: 276.736 m/s
# Freestream velocity at burnOut: 276.736 m/s
# Mach Number at burnOut: 0.820
# Kinetic energy at burnOut: 6.219e+05 J
#
#
# Apogee
#
# Apogee Altitude: 3149.058 m (ASL) | 3149.058 m (AGL)
# Apogee Time: 25.086 s
# Apogee Freestream Speed: 19.999 m/s
#
#
# Events
#
# Drogue Ejection Triggered at: 25.095 s
# Drogue Parachute Inflated at: 26.595 s
# Drogue Parachute Inflated with Freestream Speed of: 24.728 m/s
# Drogue Parachute Inflated at Height of: 3138.019 m (AGL)
# Main Ejection Triggered at: 158.924 s
# Main Parachute Inflated at: 160.424 s
# Main Parachute Inflated with Freestream Speed of: 16.760 m/s
# Main Parachute Inflated at Height of: 774.821 m (AGL)
#
#
# Impact
#
# X Impact: 0.000 m
# Y Impact: 651.833 m
# Time of Impact: 308.804 s
# Velocity at Impact: -5.098 m/s
#
#
# Maximum Values
#
# Maximum Speed: 283.752 m/s at 3.36 s
# Maximum Mach Number: 0.839 Mach at 3.36 s
# Maximum Reynolds Number: 2.374e+06 at 3.31 s
# Maximum Dynamic Pressure: 4.699e+04 Pa at 3.34 s
# Maximum Acceleration: 104.794 m/s² at 0.15 s
# Maximum Gs: 10.686 g at 0.15 s
# Maximum Upper Rail Button Normal Force: 0.298 N
# Maximum Upper Rail Button Shear Force: 0.298 N
# Maximum Lower Rail Button Normal Force: 0.298 N
# Maximum Lower Rail Button Shear Force: 0.298 N

# %%
dir(TestFlight)
# Out:
# ['FlightPhases',
#  'M1',
#  'M2',
#  'M3',
#  'MachNumber',
#  'R1',
#  'R2',
#  'R3',
#  'ReynoldsNumber',
#  'TimeNodes',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'acceleration',
#  'aerodynamicBendingMoment',
#  'aerodynamicDrag',
#  'aerodynamicLift',
#  'aerodynamicSpinMoment',
#  'allInfo',
#  'alpha1',
#  'alpha2',
#  'alpha3',
#  'angleOfAttack',
#  'animate',
#  'apogee',
#  'apogeeFreestreamSpeed',
#  'apogeeState',
#  'apogeeTime',
#  'apogeeX',
#  'apogeeY',
#  'atol',
#  'attitudeAngle',
#  'attitudeFrequencyResponse',
#  'attitudeVectorX',
#  'attitudeVectorY',
#  'attitudeVectorZ',
#  'ax',
#  'ay',
#  'az',
#  'calculateFinFlutterAnalysis',
#  'calculateStallWindVelocity',
#  'density',
#  'dragPower',
#  'dynamicPressure',
#  'dynamicViscosity',
#  'e0',
#  'e1',
#  'e2',
#  'e3',
#  'effective1RL',
#  'effective2RL',
#  'env',
#  'exportPressures',
#  'flightPhases',
#  'freestreamSpeed',
#  'frontalSurfaceWind',
#  'functionEvaluations',
#  'functionEvaluationsPerTimeStep',
#  'heading',
#  'horizontalSpeed',
#  'impactState',
#  'impactVelocity',
#  'inclination',
#  'info',
#  'initialDerivative',
#  'initialSolution',
#  'kineticEnergy',
#  'lateralAttitudeAngle',
#  'lateralSurfaceWind',
#  'maxAcceleration',
#  'maxAccelerationTime',
#  'maxDynamicPressure',
#  'maxDynamicPressureTime',
#  'maxMachNumber',
#  'maxMachNumberTime',
#  'maxRailButton1NormalForce',
#  'maxRailButton1ShearForce',
#  'maxRailButton2NormalForce',
#  'maxRailButton2ShearForce',
#  'maxReynoldsNumber',
#  'maxReynoldsNumberTime',
#  'maxSpeed',
#  'maxSpeedTime',
#  'maxTime',
#  'maxTimeStep',
#  'maxtotalPressure',
#  'maxtotalPressureTime',
#  'minTimeStep',
#  'omega1FrequencyResponse',
#  'omega2FrequencyResponse',
#  'omega3FrequencyResponse',
#  'outOfRailState',
#  'outOfRailTime',
#  'outOfRailVelocity',
#  'parachuteCdS',
#  'parachuteEvents',
#  'parachutes',
#  'pathAngle',
#  'phi',
#  'plot3dTrajectory',
#  'plotAngularKinematicsData',
#  'plotAttitudeData',
#  'plotEnergyData',
#  'plotFlightPathAngleData',
#  'plotFluidMechanicsData',
#  'plotLinearKinematicsData',
#  'plotPressureSignals',
#  'plotStabilityAndControlData',
#  'plotTrajectoryForceData',
#  'postProcess',
#  'postProcessed',
#  'potentialEnergy',
#  'pressure',
#  'printInitialConditionsData',
#  'printNumericalIntegrationSettings',
#  'psi',
#  'railButton1NormalForce',
#  'railButton1ShearForce',
#  'railButton2NormalForce',
#  'railButton2ShearForce',
#  'rocket',
#  'rotationalEnergy',
#  'rtol',
#  'solution',
#  'speed',
#  'speedOfSound',
#  'staticMargin',
#  'streamVelocityX',
#  'streamVelocityY',
#  'streamVelocityZ',
#  't',
#  'tFinal',
#  'tInitial',
#  'terminateOnApogee',
#  'theta',
#  'thrustPower',
#  'timeIterator',
#  'timeOvershoot',
#  'timeSteps',
#  'totalEnergy',
#  'totalPressure',
#  'translationalEnergy',
#  'uDot',
#  'uDotParachute',
#  'uDotRail1',
#  'uDotRail2',
#  'vx',
#  'vy',
#  'vz',
#  'w1',
#  'w2',
#  'w3',
#  'windVelocityX',
#  'windVelocityY',
#  'x',
#  'xImpact',
#  'y',
#  'yImpact',
#  'z',
#  'zImpact']

# %%
help(Calisto.setRailButtons)
# Out:
# Help on method setRailButtons in module rocketpy.Rocket:
#
# setRailButtons(distanceToCM, angularPosition=45) method of rocketpy.Rocket.Rocket instance
#     Adds rail buttons to the rocket, allowing for the
#     calculation of forces exerted by them when the rocket is
#     sliding in the launch rail. Furthermore, rail buttons are
#     also needed for the simulation of the planar flight phase,
#     when the rocket experiences 3 degrees of freedom motion while
#     only one rail button is still in the launch rail.
#
#     Parameters
#     ----------
#     distanceToCM : tuple, list, array
#         Two values organized in a tuple, list or array which
#         represent the distance of each of the two rail buttons
#         to the center of mass of the rocket without propellant.
#         If the rail button is positioned above the center of mass,
#         its distance should be a positive value. If it is below,
#         its distance should be a negative value. The order does
#         not matter. All values should be in meters.
#     angularPosition : float
#         Angular postion of the rail buttons in degrees measured
#         as the rotation around the symmetry axis of the rocket
#         relative to one of the other principal axis.
#         Default value is 45 degrees, generally used in rockets with
#         4 fins.
#
#     Returns
#     -------
#     None

# %%
max_deflections =[]
for numerator in range(0,6):
    point = numerator / 10
    Calisto.setRailButtons([point, -0.5])
    print(f"Launching with top rail button at {point}")
    TestFlight = Flight(rocket=Calisto, environment=Env, inclination=85, heading=0)
    TestFlight.postProcess()
    maxDeflections.append(TestFlight
# Out:
# Launching with top rail button at 0.0
# Launching with top rail button at 0.1
# Launching with top rail button at 0.2
# Launching with top rail button at 0.3
# Launching with top rail button at 0.4
# Launching with top rail button at 0.5
# /Users/capel010/.pyenv/versions/3.9.9/lib/python3.9/site-packages/rocketpy/Function.py:1485: RuntimeWarning: invalid value encountered in true_divide
#   Ys = self.source[:, 1] / other
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/.pyenv/versions/3.9.9/lib/python3.9/site-packages/rocketpy/Function.py:1460, in Function.__truediv__(self, other)
#    1456 try:
#    1457     # Check if Function objects source is array or callable
#    1458     # Check if Function objects have same interpolation and domain
#    1459     if (
# -> 1460         isinstance(other.source, np.ndarray)
#    1461         and isinstance(self.source, np.ndarray)
#    1462         and self.__interpolation__ == other.__interpolation__
#    1463         and self.__inputs__ == other.__inputs__
#    1464         and np.any(self.source[:, 0] - other.source[:, 0]) == False
#    1465     ):
#    1466         # Operate on grid values
#    1467         Ys = self.source[:, 1] / other.source[:, 1]
#
# AttributeError: 'float' object has no attribute 'source'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [17], in <module>
#       5 print(f"Launching with top rail button at {point}")
#       6 TestFlight = Flight(rocket=Calisto, environment=Env, inclination=85, heading=0)
# ----> 7 TestFlight.postProcess()
#
# File ~/.pyenv/versions/3.9.9/lib/python3.9/site-packages/rocketpy/Flight.py:1734, in Flight.postProcess(self)
#    1728 D1 = self.rocket.railButtons.distanceToCM[
#    1729     0
#    1730 ]  # Distance from Rail Button 1 (upper) to CM
#    1731 D2 = self.rocket.railButtons.distanceToCM[
#    1732     1
#    1733 ]  # Distance from Rail Button 2 (lower) to CM
# -> 1734 F11 = (self.R1 * D2 - self.M2) / (
#    1735     D1 + D2
#    1736 )  # Rail Button 1 force in the 1 direction
#    1737 F12 = (self.R2 * D2 + self.M1) / (
#    1738     D1 + D2
#    1739 )  # Rail Button 1 force in the 2 direction
#    1740 F21 = (self.R1 * D1 + self.M2) / (
#    1741     D1 + D2
#    1742 )  # Rail Button 2 force in the 1 direction
#
# File ~/.pyenv/versions/3.9.9/lib/python3.9/site-packages/rocketpy/Function.py:1494, in Function.__truediv__(self, other)
#    1492     interpolation = self.__interpolation__
#    1493     # Create new Function object
# -> 1494     return Function(source, inputs, outputs, interpolation)
#    1495 else:
#    1496     return Function(lambda x: (self.getValueOpt2(x) / other))
#
# File ~/.pyenv/versions/3.9.9/lib/python3.9/site-packages/rocketpy/Function.py:85, in Function.__init__(self, source, inputs, outputs, interpolation, extrapolation)
#      83 self.last_interval = 0
#      84 # Set source
# ---> 85 self.setSource(source)
#      86 # Return
#      87 return None
#
# File ~/.pyenv/versions/3.9.9/lib/python3.9/site-packages/rocketpy/Function.py:204, in Function.setSource(self, source)
#     201         self.setInterpolation()
#     202     else:
#     203         # Updates interpolation coefficients
# --> 204         self.setInterpolation(self.__interpolation__)
#     205 # Do things if function is multivariate
#     206 else:
#     207     # Finally set data source as source
#     208     self.source = source
#
# File ~/.pyenv/versions/3.9.9/lib/python3.9/site-packages/rocketpy/Function.py:237, in Function.setInterpolation(self, method)
#     234 # Spline, akima and polynomial need data processing
#     235 # Shepard, and linear do not
#     236 if method == "spline":
# --> 237     self.__interpolateSpline__()
#     238 elif method == "polynomial":
#     239     self.__interpolatePolynomial__()
#
# File ~/.pyenv/versions/3.9.9/lib/python3.9/site-packages/rocketpy/Function.py:1380, in Function.__interpolateSpline__(self)
#    1378 B.append(0)
#    1379 # Solve the system for c coefficients
# -> 1380 c = linalg.solve_banded((1, 1), Ab, B, True, True)
#    1381 # Calculate other coefficients
#    1382 b = [
#    1383     ((y[i + 1] - y[i]) / h[i] - h[i] * (2 * c[i] + c[i + 1]) / 3)
#    1384     for i in range(0, mdim - 1)
#    1385 ]
#
# File ~/.pyenv/versions/3.9.9/lib/python3.9/site-packages/scipy/linalg/basic.py:443, in solve_banded(l_and_u, ab, b, overwrite_ab, overwrite_b, debug, check_finite)
#     438     warn('Use of the "debug" keyword is deprecated '
#     439          'and this keyword will be removed in the future '
#     440          'versions of SciPy.', DeprecationWarning, stacklevel=2)
#     442 a1 = _asarray_validated(ab, check_finite=check_finite, as_inexact=True)
# --> 443 b1 = _asarray_validated(b, check_finite=check_finite, as_inexact=True)
#     444 # Validate shapes.
#     445 if a1.shape[-1] != b1.shape[0]:
#
# File ~/.pyenv/versions/3.9.9/lib/python3.9/site-packages/scipy/_lib/_util.py:293, in _asarray_validated(a, check_finite, sparse_ok, objects_ok, mask_ok, as_inexact)
#     291         raise ValueError('masked arrays are not supported')
#     292 toarray = np.asarray_chkfinite if check_finite else np.asarray
# --> 293 a = toarray(a)
#     294 if not objects_ok:
#     295     if a.dtype is np.dtype('O'):
#
# File ~/.pyenv/versions/3.9.9/lib/python3.9/site-packages/numpy/lib/function_base.py:603, in asarray_chkfinite(a, dtype, order)
#     601 a = asarray(a, dtype=dtype, order=order)
#     602 if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
# --> 603     raise ValueError(
#     604         "array must not contain infs or NaNs")
#     605 return a
#
# ValueError: array must not contain infs or NaNs
